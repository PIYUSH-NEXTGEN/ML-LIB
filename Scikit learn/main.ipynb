# %%
# Import the built-in Breast Cancer dataset from scikit-learn
from sklearn.datasets import load_breast_cancer

# Import the function used to split data into training and testing sets
from sklearn.model_selection import train_test_split

# Import StandardScaler to standardize/scale the feature values
from sklearn.preprocessing import StandardScaler

# Import KNeighborsClassifier, the K-Nearest Neighbors classification algorithm
from sklearn.neighbors import KNeighborsClassifier

# %%
# Load the Breast Cancer dataset and directly return its features (X) and target labels (y)
X, y = load_breast_cancer(return_X_y=True)

# %%
# Split X and y into training data (80%) and testing data (20%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Create a StandardScaler object that will be used to standardize the features
scaler = StandardScaler()

# Learn the mean and standard deviation from the training data, then scale the training data
X_train_scaled = scaler.fit_transform(X_train)

# Scale the test data using the mean and standard deviation learned from the training data
X_test_scaled = scaler.transform(X_test)

# %%
# Create a K-Nearest Neighbors classifier using its default parameters
knn = KNeighborsClassifier()

# Train the KNN classifier using the scaled training features and their corresponding labels
knn.fit(X_train_scaled, y_train)
# Out:
# KNeighborsClassifier()

# %%
print(knn.score(X_test_scaled, y_test))
# Out:
# 0.956140350877193

# %%
# Import pyplot from Matplotlib and give it the alias "plt"
# Matplotlib is used for creating graphs and visualizations
import matplotlib.pyplot as plt

# Import make_blobs from scikit-learn
# make_blobs() is used to generate synthetic data points arranged in clusters
from sklearn.datasets import make_blobs

# %%
# Generate 5000 synthetic data points divided into 5 clusters
# X contains the features/coordinates of the data points
# y contains the cluster label for each data point
X, y = make_blobs(n_samples=5000, centers=5)


# Display the X array containing all 5000 data points
# Each row represents one data point and contains 2 features
X
# Out:
# array([[-5.78577827,  6.38379964],
#        [ 2.36838766,  5.02991327],
#        [ 0.73174896,  2.10565101],
#        ...,
#        [-4.79052669,  7.52884286],
#        [-7.21328852,  5.43765032],
#        [-6.38095763,  3.83414676]], shape=(5000, 2))

# %%
# Create a scatter plot
# X[:, 0] → all rows from column 0 → used for the x-axis
# X[:, 1] → all rows from column 1 → used for the y-axis
# c=y     → color each point according to its cluster label
plt.scatter(X[:, 0], X[:, 1], c=y)

# %%
# Import the built-in Iris dataset from scikit-learn
from sklearn.datasets import load_iris

# Import train_test_split to divide the dataset into training and testing sets
from sklearn.model_selection import train_test_split


# Load the Iris dataset
# 'data' is a Bunch object containing the dataset, labels, feature names, etc.
data = load_iris()

# Extract the feature data into X and the target labels into y
# X contains 150 samples with 4 features each
# y contains the class label (0, 1, or 2) for each sample
X, y = data.data, data.target

# %%
# Split the dataset into training and testing sets
# test_size=0.2 means 20% of the data is used for testing
# and the remaining 80% is used for training
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2
)

# %%
# Get the number of samples in the training set
len(X_train)
# Out:
# 120

# %%
# Get the number of samples in the testing set
len(X_test)
# Out:
# 30

# %%
# Import NumPy and give it the alias "np"
import numpy as np

# %%
# Count how many times each class label appears in y_train
# For example, [39, 41, 40] means:
# class 0 → 39 samples
# class 1 → 41 samples
# class 2 → 40 samples
count = np.bincount(y_train)

# Create positions [0, 1, 2] for the three classes
# These positions will be used on the x-axis of the bar chart
positions = np.arange(3)


# Create a bar chart
# positions → x-axis positions [0, 1, 2]
# count     → height of each bar (number of samples in each class)
plt.bar(positions, count)


# Replace the numerical x-axis labels (0, 1, 2)
# with the actual class names:
# setosa, versicolor, virginica
plt.xticks(positions, data.target_names)
# Out:
# ([<matplotlib.axis.XTick at 0x1c566eac690>,
# ...
#  [Text(0, 0, 'setosa'), Text(1, 0, 'versicolor'), Text(2, 0, 'virginica')])

# %%
from sklearn.datasets import load_iris
data = load_iris()

X, y = data.data, data.target


# Import StratifiedShuffleSplit
from sklearn.model_selection import StratifiedShuffleSplit

# Create a splitter
# n_splits=1 -> create one train/test split
# test_size=0.2 -> 20% test, 80% train
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2)

# Generate train and test indices
for train_idx, test_idx in split.split(X, y):

    # Select the corresponding rows from X
    X_train, X_test = X[train_idx], X[test_idx]

    # Select the corresponding labels from y
    y_train, y_test = y[train_idx], y[test_idx]


# -----------------------------
# Preprocessing
# -----------------------------

# Import MinMaxScaler
from sklearn.preprocessing import MinMaxScaler

# Create the scaler object
scaler = MinMaxScaler()

# Learn min/max from training data and scale it
X_train_scaled = scaler.fit_transform(X_train)

# Scale test data using the SAME min/max learned from training data
X_test_scaled = scaler.transform(X_test)

# Display scaled training data
X_train_scaled
# Out:
# array([[0.19444444, 0.66666667, 0.06779661, 0.04166667],
#        [0.55555556, 0.375     , 0.77966102, 0.70833333],
#        [0.13888889, 0.41666667, 0.06779661, 0.08333333],
#        [0.30555556, 0.79166667, 0.11864407, 0.125     ],
#        [0.25      , 0.875     , 0.08474576, 0.        ],
#        [0.38888889, 0.20833333, 0.6779661 , 0.79166667],
#        [0.41666667, 0.25      , 0.50847458, 0.45833333],
#        [0.22222222, 0.625     , 0.06779661, 0.08333333],
#        [0.19444444, 0.125     , 0.38983051, 0.375     ],
#        [0.86111111, 0.33333333, 0.86440678, 0.75      ],
#        [0.72222222, 0.45833333, 0.74576271, 0.83333333],
#        [0.44444444, 0.41666667, 0.54237288, 0.58333333],
#        [0.19444444, 0.        , 0.42372881, 0.375     ],
#        [0.05555556, 0.125     , 0.05084746, 0.08333333],
#        [0.75      , 0.5       , 0.62711864, 0.54166667],
#        [0.55555556, 0.54166667, 0.62711864, 0.625     ],
# ...

# %%
# Import MinMaxScaler
from sklearn.preprocessing import MinMaxScaler

# Create the scaler object
scaler = MinMaxScaler()

# Learn min/max from training data and scale it
X_train_scaled = scaler.fit_transform(X_train)

# Scale test data using the SAME min/max learned from training data
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[0.19444444, 0.66666667, 0.06779661, 0.04166667],
#        [0.55555556, 0.375     , 0.77966102, 0.70833333],
#        [0.13888889, 0.41666667, 0.06779661, 0.08333333],
#        [0.30555556, 0.79166667, 0.11864407, 0.125     ],
#        [0.25      , 0.875     , 0.08474576, 0.        ],
#        [0.38888889, 0.20833333, 0.6779661 , 0.79166667],
#        [0.41666667, 0.25      , 0.50847458, 0.45833333],
#        [0.22222222, 0.625     , 0.06779661, 0.08333333],
#        [0.19444444, 0.125     , 0.38983051, 0.375     ],
#        [0.86111111, 0.33333333, 0.86440678, 0.75      ],
#        [0.72222222, 0.45833333, 0.74576271, 0.83333333],
#        [0.44444444, 0.41666667, 0.54237288, 0.58333333],
#        [0.19444444, 0.        , 0.42372881, 0.375     ],
#        [0.05555556, 0.125     , 0.05084746, 0.08333333],
#        [0.75      , 0.5       , 0.62711864, 0.54166667],
#        [0.55555556, 0.54166667, 0.62711864, 0.625     ],
# ...

# %%
# Import fetch_openml()
# This function downloads datasets from the OpenML repository
from sklearn.datasets import fetch_openml

# Import OrdinalEncoder
# This is used to convert categorical feature values into numerical values
from sklearn.preprocessing import OrdinalEncoder


# Download the "car" dataset from OpenML
# as_frame=True tells scikit-learn to return the data in pandas DataFrame format
# .frame extracts the DataFrame from the object returned by fetch_openml()
data = fetch_openml('car', as_frame=True).frame

# Display the car dataset
data
# Out:
# c:\Users\piyus\Learning-collections\.venv-1\Lib\site-packages\sklearn\datasets\_openml.py:328: UserWarning: Multiple active versions of the dataset matching the name car exist. Versions may be fundamentally different, returning version 2. Available versions:
# - version 2, status: active
#   url: https://www.openml.org/search?type=data&id=991
# - version 3, status: active
#   url: https://www.openml.org/search?type=data&id=40975
#
#   warn(warning_msg)
#      buying  maint  doors persons lug_boot safety binaryClass
# 0     vhigh  vhigh      2       2    small    low           P
# 1     vhigh  vhigh      2       2    small    med           P
# 2     vhigh  vhigh      2       2    small   high           P
# 3     vhigh  vhigh      2       2      med    low           P
# 4     vhigh  vhigh      2       2      med    med           P
# ...     ...    ...    ...     ...      ...    ...         ...
# 1723    low    low  5more    more      med    med           N
# ...

# %%
# Import the built-in Breast Cancer dataset from scikit-learn
from sklearn.datasets import load_breast_cancer

# Import the function used to split data into training and testing sets
from sklearn.model_selection import train_test_split

# Import StandardScaler for standardizing numerical features
from sklearn.preprocessing import StandardScaler


# Load the Breast Cancer dataset
# return_X_y=True tells sklearn to directly return:
# X = features
# y = target labels
X, y = load_breast_cancer(return_X_y=True)


# Split the data into training and testing sets
# X_train → training features
# X_test  → testing features
# y_train → labels for training data
# y_test  → labels for testing data
# test_size=0.2 → 20% test data and 80% training data
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2
)


# Create a StandardScaler object
# This object will learn the mean and standard deviation
# of each feature from the training data
scaler = StandardScaler()


# fit_transform() does two things:
#
# 1. fit()       → learn mean and standard deviation from X_train
# 2. transform() → standardize X_train using those learned values
#
# The result is stored in X_train_scaled
X_train_scaled = scaler.fit_transform(X_train)


# Transform the test data using the SAME mean and standard deviation
# learned from X_train.
#
# We use transform(), NOT fit_transform(), because fitting on the
# test data would cause data leakage.
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier

# Create the KNN classifier
clf = KNeighborsClassifier()

# Train the classifier using the scaled training data
clf.fit(X_train_scaled, y_train)
# Out:
# KNeighborsClassifier()

# %%
# Evaluate the classifier on the scaled test data
# For KNeighborsClassifier, this returns accuracy
clf.score(X_test_scaled, y_test)
# Out:
# 0.9736842105263158

# %%
# Select the first sample from the test dataset
single_instance = X_test_scaled[0]

single_instance
# Out:
# array([-0.04329385,  0.44766902, -0.10412974, -0.1598945 , -0.39369813,
#        -0.65605103, -0.9261381 , -0.75937808, -1.06322691, -0.63216829,
#        -0.51856851,  0.53273783, -0.58230428, -0.39301958,  0.12283585,
#        -0.65786869, -0.90461393, -0.29044487, -0.95705437, -0.34197914,
#        -0.2085246 ,  0.74507205, -0.28028751, -0.30160399, -0.14176281,
#        -0.6598371 , -1.00796961, -0.53470343, -1.08961579, -0.43073722])

# %%
# Predict the class of that one sample
# [single_instance] converts the single 1D sample into
# the 2D format expected by scikit-learn: (1, 30)
clf.predict([single_instance])
# Out:
# array([1])

# %%
y_test[2]
# Out:
# np.int64(1)

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()
clf.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
clf.score(X_test_scaled, y_test)
# Out:
# 0.9912280701754386

# %%
single_instance = X_test_scaled[0]
single_instance
# Out:
# array([-0.04329385,  0.44766902, -0.10412974, -0.1598945 , -0.39369813,
#        -0.65605103, -0.9261381 , -0.75937808, -1.06322691, -0.63216829,
#        -0.51856851,  0.53273783, -0.58230428, -0.39301958,  0.12283585,
#        -0.65786869, -0.90461393, -0.29044487, -0.95705437, -0.34197914,
#        -0.2085246 ,  0.74507205, -0.28028751, -0.30160399, -0.14176281,
#        -0.6598371 , -1.00796961, -0.53470343, -1.08961579, -0.43073722])

# %%
clf.predict([single_instance])
# Out:
# array([1])

# %%
y_test[2]
# Out:
# np.int64(1)

# %%
from sklearn.ensemble import RandomForestClassifier
clf = LogisticRegression()
clf.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
clf.score(X_test_scaled, y_test)
# Out:
# 0.9912280701754386

# %%
single_instance = X_test_scaled[0]
single_instance
# Out:
# array([-0.04329385,  0.44766902, -0.10412974, -0.1598945 , -0.39369813,
#        -0.65605103, -0.9261381 , -0.75937808, -1.06322691, -0.63216829,
#        -0.51856851,  0.53273783, -0.58230428, -0.39301958,  0.12283585,
#        -0.65786869, -0.90461393, -0.29044487, -0.95705437, -0.34197914,
#        -0.2085246 ,  0.74507205, -0.28028751, -0.30160399, -0.14176281,
#        -0.6598371 , -1.00796961, -0.53470343, -1.08961579, -0.43073722])

# %%
clf.predict([single_instance])
# Out:
# array([1])

# %%
y_test[2]
# Out:
# np.int64(1)

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X, y = fetch_california_housing(return_X_y = True)
X_train , X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2)

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
reg.score(X_test_scaled, y_test)
# Out:
# 0.5915786044928557

# %%
single_instance = X_test_scaled[0]
single_instance
# Out:
# array([ 0.7671833 ,  0.58100878,  0.27573801, -0.16160132, -0.52257363,
#         0.12463526, -0.81460817,  0.7708287 ])

# %%
reg.predict([single_instance])
# Out:
# array([2.7092886])

# %%
# Import make_blobs from scikit-learn.
# make_blobs() generates synthetic data points arranged into clusters.
from sklearn.datasets import make_blobs

# Import StandardScaler.
# It standardizes numerical features so they have approximately
# mean = 0 and standard deviation = 1.
from sklearn.preprocessing import StandardScaler

# Import KMeans, the clustering algorithm we will use later
# to discover groups in the data.
from sklearn.cluster import KMeans

# %%
# Generate 5000 synthetic data points arranged around 5 centers.
#
# X → the generated feature data
# _ → the generated cluster labels, which we intentionally ignore
#
# n_samples=5000 → generate 5000 data points
# centers=5 → generate 5 clusters
# random_state=10 → make the generated data reproducible
X, _ = make_blobs(
    n_samples=5000,
    centers=5,
    random_state=10
)


# Display the generated feature data.
# In a Jupyter notebook, writing X by itself displays the array.
X
# Out:
# array([[  6.17306585, -10.25446247],
#        [ -8.13981972,   4.45135687],
#        [  2.71307241,   4.32686739],
#        ...,
#        [ -6.91896111,   4.29323728],
#        [ -3.95595105,   4.23150467],
#        [  0.91461712,  -7.45569288]], shape=(5000, 2))

# %%
# Create a StandardScaler object.
# This object will be used to standardize the features.
scaler = StandardScaler()


# First learn the mean and standard deviation of each feature,
# then use those values to standardize X.
#
# fit()       → learn statistics from X
# transform() → scale X using those statistics
# fit_transform() → performs both operations together
X_scaled = scaler.fit_transform(X)

# %%
import matplotlib.pyplot as plt
# X_scaled[:, 0]
# → all rows, column 0
# → first feature → x-axis
#
# X_scaled[:, 1]
# → all rows, column 1
# → second feature → y-axis
plt.scatter(X_scaled[:, 0], X_scaled[:, 1])

# %%
kmeans = KMeans(n_clusters=5)
# K-Means will:
# 1. Initialize 5 centroids
# 2. Assign each point to its nearest centroid
# 3. Recalculate the centroid of each cluster
# 4. Repeat until the clusters converge
kmeans.fit(X_scaled)
# Out:
# KMeans(n_clusters=5)

# %%
plt.scatter(X_scaled[:,0], X_scaled[:,1], c = kmeans.labels_)

# %%
from sklearn.datasets import fetch_openml
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
# Load the MNIST handwritten digit dataset from OpenML.
# X contains the input features (784 pixel values for each image).
# y contains the target labels (the actual digit: 0 to 9). 
# Each MNIST image is 28 × 28 pixels: 
# 28 * 28 = 784 features.
X, y = fetch_openml('mnist_784' , return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size =0.2, random_state=0)

# %%
# Create a PCA object that will reduce the number of features
# from 784 (28 × 28 pixels) to 10 principal components.
pca = PCA(n_components=10)
X_train_reduced = pca.fit_transform(X_train)
X_test_reduced = pca.transform(X_test)

# %%
X_train.shape
# Out:
# (56000, 784)

# %%
X_train_reduced.shape
# Out:
# (56000, 10)

# %%
# max_iter=100 means the optimization algorithm can perform
# at most 100 iterations while trying to find the best
clf =  LogisticRegression(max_iter = 100)
clf.fit(X_train_reduced, y_train)
print(clf.score(X_test_reduced, y_test))
# Out:
# 0.8006428571428571
# c:\Users\piyus\Learning-collections\.venv-1\Lib\site-packages\sklearn\linear_model\_logistic.py:599: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
pca.explained_variance_ratio_
# Out:
# array([0.09747258, 0.07171133, 0.06165926, 0.05418112, 0.04859922,
#        0.04303424, 0.03290366, 0.02885822, 0.02752979, 0.02343808])

# %%
clf.score(X_test_reduced, y_test)
# Out:
# 0.8006428571428571

# %%
from sklearn.metrics import accuracy_score , precision_score, f1_score, recall_score

y_pred = clf.predict(X_test_reduced)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8006428571428571
